# %% [markdown]
# <a href="https://colab.research.google.com/github/sidchoudhuri/c64-match/blob/main/C64MatchingGame.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
import time

def create_board(size):
    """Create board"""
    if size * size % 2 != 0:
        print("Error: The board must be an even number of cells!")
        return None

    # List of 2-char symbols
    symbols = ['C=', '64', '8B', 'm0', 'F1', 'F3', 'F5', 'F7']
    # Remember to add symbols if board is bigger than 4x4
    if size * size // 2 > len(symbols):
        symbols = symbols * (size * size // 2 // len(symbols) + 1)

    board_symbols = symbols[:(size * size // 2)] * 2
    random.shuffle(board_symbols)

    grid = []
    for _ in range(size):
        row = [board_symbols.pop() for _ in range(size)]
        grid.append(row)

    return grid

def display_board(board, revealed_status):
    """Display board to con, formatted for 2-char symbols"""
    # Print column with  spacing
    print("  " + " ".join(f"{i:2}" for i in range(len(board))))
    for i, row in enumerate(board):
        print(f"{i} ", end="")
        for j, cell in enumerate(row):
            if revealed_status[i][j]:
                # Print the 2-char symbol
                print(f"{cell}", end=" ")
            else:
                # Print 2-chars for alignment
                print("XX", end=" ")
        print()
    print("-" * (len(board) * 3 + 2)) # Separator line

def get_player_move(board_size, message):
    """Player input"""
    while True:
        try:
            position = input(message + f" (row col, e.g., 0 1): ")
            row, col = map(int, position.split())
            if 0 <= row < board_size and 0 <= col < board_size:
                return row, col
            else:
                print("Invalid coordinates!")
        except (ValueError, IndexError):
            print("Invalid input. Enter two numbers separated by a space.")

def play_game():
    """Main game loop"""
    print("Welcome to m0nde's C64 Match!")

    board_size = 4
    board = create_board(board_size)
    if board is None:
        return

    revealed_status = [[False for _ in range(board_size)] for _ in range(board_size)]
    matched_pairs = 0
    total_pairs = board_size * board_size // 2
    moves_made = 0 # Initialize move counter

    while matched_pairs < total_pairs:
        # Clear screen to hide old state
        print("\n" * 50)

        # Display move counter
        print(f"Moves made: {moves_made}")

        # Display the current state of the board
        display_board(board, revealed_status)

        # Get first guess
        row1, col1 = get_player_move(board_size, "Enter coordinates for the first symbol")
        if revealed_status[row1][col1]:
            print("That's already been matched. Try again.")
            time.sleep(1)
            continue
        revealed_status[row1][col1] = True

        # Display board with 1st selection revealed
        display_board(board, revealed_status)

        # Get second guess
        row2, col2 = get_player_move(board_size, "Enter coordinates for the 2nd symbol")
        # Check if tile was selected twice or is already matched
        if (row1, col1) == (row2, col2) or revealed_status[row2][col2]:
            print("Invalid selection. Try again.")
            revealed_status[row1][col1] = False # Hide the 1st symbol
            time.sleep(1)
            continue
        revealed_status[row2][col2] = True

        # Display board with both revealed
        display_board(board, revealed_status)

        # Valid turn completed, increment moves counter
        moves_made += 1

        # Check for match
        if board[row1][col1] == board[row2][col2]:
            print("It's a match!")
        else:
            print("No match. Take a moment to remember their positions!")
            input("Press Enter to continue...") # Wait for input
            revealed_status[row1][col1] = False
            revealed_status[row2][col2] = False

    print(f"Congrats! You matched all the symbols in {moves_made} moves!")

if __name__ == "__main__":
    play_game()
# Out:
# Welcome to m0nde's C64 Memory Game!
#    0  1  2  3
# 0 XX XX XX XX
# 1 XX XX XX XX
# 2 XX XX XX XX
# 3 XX XX XX XX
# --------------
# Enter the coordinates for your first guess (row col, e.g., 0 1): 0 0
#    0  1  2  3
# 0 8B XX XX XX
# 1 XX XX XX XX
# 2 XX XX XX XX
# 3 XX XX XX XX
# --------------
# Enter the coordinates for your second guess (row col, e.g., 0 1): 0 1
#    0  1  2  3
# 0 8B m0 XX XX
# 1 XX XX XX XX
# 2 XX XX XX XX
# 3 XX XX XX XX
# --------------
# No match. Take a moment to remember their positions!
# Press Enter to continue...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#    0  1  2  3
# 0 XX XX XX XX
# 1 XX XX XX XX
# 2 XX XX XX XX
# 3 XX XX XX XX
# --------------
# Enter the coordinates for your first guess (row col, e.g., 0 1): 0 2
#    0  1  2  3
# 0 XX XX F5 XX
# 1 XX XX XX XX
# 2 XX XX XX XX
# 3 XX XX XX XX
# --------------
# Enter the coordinates for your second guess (row col, e.g., 0 1): 0 3
#    0  1  2  3
# 0 XX XX F5 F7
# 1 XX XX XX XX
# 2 XX XX XX XX
# 3 XX XX XX XX
# --------------
# No match. Take a moment to remember their positions!
# Press Enter to continue...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#    0  1  2  3
# 0 XX XX XX XX
# 1 XX XX XX XX
# 2 XX XX XX XX
# 3 XX XX XX XX
# --------------
# Enter the coordinates for your first guess (row col, e.g., 0 1): 1 0
#    0  1  2  3
# 0 XX XX XX XX
# 1 F7 XX XX XX
# 2 XX XX XX XX
# 3 XX XX XX XX
# --------------
# Enter the coordinates for your second guess (row col, e.g., 0 1): 0 3
#    0  1  2  3
# 0 XX XX XX F7
# 1 F7 XX XX XX
# 2 XX XX XX XX
# 3 XX XX XX XX
# --------------
# It's a match!
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#    0  1  2  3
# 0 XX XX XX F7
# 1 F7 XX XX XX
# 2 XX XX XX XX
# 3 XX XX XX XX
# --------------
# Enter the coordinates for your first guess (row col, e.g., 0 1): 1 1
#    0  1  2  3
# 0 XX XX XX F7
# 1 F7 C= XX XX
# 2 XX XX XX XX
# 3 XX XX XX XX
# --------------
# Enter the coordinates for your second guess (row col, e.g., 0 1): 1 2
#    0  1  2  3
# 0 XX XX XX F7
# 1 F7 C= F1 XX
# 2 XX XX XX XX
# 3 XX XX XX XX
# --------------
# No match. Take a moment to remember their positions!
# Press Enter to continue...1 3
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#    0  1  2  3
# 0 XX XX XX F7
# 1 F7 XX XX XX
# 2 XX XX XX XX
# 3 XX XX XX XX
# --------------
# Enter the coordinates for your first guess (row col, e.g., 0 1): 1 3
#    0  1  2  3
# 0 XX XX XX F7
# 1 F7 XX XX F3
# 2 XX XX XX XX
# 3 XX XX XX XX
# --------------
# Enter the coordinates for your second guess (row col, e.g., 0 1): 0 2
#    0  1  2  3
# 0 XX XX F5 F7
# 1 F7 XX XX F3
# 2 XX XX XX XX
# 3 XX XX XX XX
# --------------
# No match. Take a moment to remember their positions!
# Press Enter to continue...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#    0  1  2  3
# 0 XX XX XX F7
# 1 F7 XX XX XX
# 2 XX XX XX XX
# 3 XX XX XX XX
# --------------
# Enter the coordinates for your first guess (row col, e.g., 0 1): 0 1
#    0  1  2  3
# 0 XX m0 XX F7
# 1 F7 XX XX XX
# 2 XX XX XX XX
# 3 XX XX XX XX
# --------------
# Enter the coordinates for your second guess (row col, e.g., 0 1): 2 0
#    0  1  2  3
# 0 XX m0 XX F7
# 1 F7 XX XX XX
# 2 8B XX XX XX
# 3 XX XX XX XX
# --------------
# No match. Take a moment to remember their positions!
# Press Enter to continue...1 2
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#    0  1  2  3
# 0 XX XX XX F7
# 1 F7 XX XX XX
# 2 XX XX XX XX
# 3 XX XX XX XX
# --------------
# Enter the coordinates for your first guess (row col, e.g., 0 1): 1 2
#    0  1  2  3
# 0 XX XX XX F7
# 1 F7 XX F1 XX
# 2 XX XX XX XX
# 3 XX XX XX XX
# --------------
# Enter the coordinates for your second guess (row col, e.g., 0 1): 2 1
#    0  1  2  3
# 0 XX XX XX F7
# 1 F7 XX F1 XX
# 2 XX 64 XX XX
# 3 XX XX XX XX
# --------------
# No match. Take a moment to remember their positions!
# Press Enter to continue...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#    0  1  2  3
# 0 XX XX XX F7
# 1 F7 XX XX XX
# 2 XX XX XX XX
# 3 XX XX XX XX
# --------------
# Enter the coordinates for your first guess (row col, e.g., 0 1):  1 1
#    0  1  2  3
# 0 XX XX XX F7
# 1 F7 C= XX XX
# 2 XX XX XX XX
# 3 XX XX XX XX
# --------------
# Enter the coordinates for your second guess (row col, e.g., 0 1): 3 3
#    0  1  2  3
# 0 XX XX XX F7
# 1 F7 C= XX XX
# 2 XX XX XX XX
# 3 XX XX XX F3
# --------------
# No match. Take a moment to remember their positions!
# Press Enter to continue...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#    0  1  2  3
# 0 XX XX XX F7
# 1 F7 XX XX XX
# 2 XX XX XX XX
# 3 XX XX XX XX
# --------------
# Enter the coordinates for your first guess (row col, e.g., 0 1): 0 2
#    0  1  2  3
# 0 XX XX F5 F7
# 1 F7 XX XX XX
# 2 XX XX XX XX
# 3 XX XX XX XX
# --------------
# Enter the coordinates for your second guess (row col, e.g., 0 1): 0 1
#    0  1  2  3
# 0 XX m0 F5 F7
# 1 F7 XX XX XX
# 2 XX XX XX XX
# 3 XX XX XX XX
# --------------
# No match. Take a moment to remember their positions!
# Press Enter to continue...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#    0  1  2  3
# 0 XX XX XX F7
# 1 F7 XX XX XX
# 2 XX XX XX XX
# 3 XX XX XX XX
# --------------
# Enter the coordinates for your first guess (row col, e.g., 0 1): 0 2
#    0  1  2  3
# 0 XX XX F5 F7
# 1 F7 XX XX XX
# 2 XX XX XX XX
# 3 XX XX XX XX
# --------------
# Enter the coordinates for your second guess (row col, e.g., 0 1): 0 2
# Invalid selection. Try again.
#    0  1  2  3
# 0 XX XX XX F7
# 1 F7 XX XX XX
# 2 XX XX XX XX
# 3 XX XX XX XX
# --------------
# Enter the coordinates for your first guess (row col, e.g., 0 1): 0 0
#    0  1  2  3
# 0 8B XX XX F7
# 1 F7 XX XX XX
# 2 XX XX XX XX
# 3 XX XX XX XX
# --------------
# Enter the coordinates for your second guess (row col, e.g., 0 1): 3 2
#    0  1  2  3
# 0 8B XX XX F7
# 1 F7 XX XX XX
# 2 XX XX XX XX
# 3 XX XX m0 XX
# --------------
# No match. Take a moment to remember their positions!
# Press Enter to continue...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#    0  1  2  3
# 0 XX XX XX F7
# 1 F7 XX XX XX
# 2 XX XX XX XX
# 3 XX XX XX XX
# --------------
# Enter the coordinates for your first guess (row col, e.g., 0 1): 0 1
#    0  1  2  3
# 0 XX m0 XX F7
# 1 F7 XX XX XX
# 2 XX XX XX XX
# 3 XX XX XX XX
# --------------
# Enter the coordinates for your second guess (row col, e.g., 0 1): 3 2
#    0  1  2  3
# 0 XX m0 XX F7
# 1 F7 XX XX XX
# 2 XX XX XX XX
# 3 XX XX m0 XX
# --------------
# It's a match!
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#    0  1  2  3
# 0 XX m0 XX F7
# 1 F7 XX XX XX
# 2 XX XX XX XX
# 3 XX XX m0 XX
# --------------
# Enter the coordinates for your first guess (row col, e.g., 0 1): 0 2
#    0  1  2  3
# 0 XX m0 F5 F7
# 1 F7 XX XX XX
# 2 XX XX XX XX
# 3 XX XX m0 XX
# --------------
# Enter the coordinates for your second guess (row col, e.g., 0 1): 1 1
#    0  1  2  3
# 0 XX m0 F5 F7
# 1 F7 C= XX XX
# 2 XX XX XX XX
# 3 XX XX m0 XX
# --------------
# No match. Take a moment to remember their positions!
# Press Enter to continue...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#    0  1  2  3
# 0 XX m0 XX F7
# 1 F7 XX XX XX
# 2 XX XX XX XX
# 3 XX XX m0 XX
# --------------
# Enter the coordinates for your first guess (row col, e.g., 0 1): 2 0
#    0  1  2  3
# 0 XX m0 XX F7
# 1 F7 XX XX XX
# 2 8B XX XX XX
# 3 XX XX m0 XX
# --------------
# Enter the coordinates for your second guess (row col, e.g., 0 1): 0 0
#    0  1  2  3
# 0 8B m0 XX F7
# 1 F7 XX XX XX
# 2 8B XX XX XX
# 3 XX XX m0 XX
# --------------
# It's a match!
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#    0  1  2  3
# 0 8B m0 XX F7
# 1 F7 XX XX XX
# 2 8B XX XX XX
# 3 XX XX m0 XX
# --------------
# Enter the coordinates for your first guess (row col, e.g., 0 1): 0 3
# That's already been matched. Try again.
#    0  1  2  3
# 0 8B m0 XX F7
# 1 F7 XX XX XX
# 2 8B XX XX XX
# 3 XX XX m0 XX
# --------------
# Enter the coordinates for your first guess (row col, e.g., 0 1): 3 0
#    0  1  2  3
# 0 8B m0 XX F7
# 1 F7 XX XX XX
# 2 8B XX XX XX
# 3 C= XX m0 XX
# --------------
# Enter the coordinates for your second guess (row col, e.g., 0 1): 2 3
#    0  1  2  3
# 0 8B m0 XX F7
# 1 F7 XX XX XX
# 2 8B XX XX F1
# 3 C= XX m0 XX
# --------------
# No match. Take a moment to remember their positions!
# Press Enter to continue...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#    0  1  2  3
# 0 8B m0 XX F7
# 1 F7 XX XX XX
# 2 8B XX XX XX
# 3 XX XX m0 XX
# --------------
# Enter the coordinates for your first guess (row col, e.g., 0 1): 2 2
#    0  1  2  3
# 0 8B m0 XX F7
# 1 F7 XX XX XX
# 2 8B XX F5 XX
# 3 XX XX m0 XX
# --------------
# Enter the coordinates for your second guess (row col, e.g., 0 1): 0 2
#    0  1  2  3
# 0 8B m0 F5 F7
# 1 F7 XX XX XX
# 2 8B XX F5 XX
# 3 XX XX m0 XX
# --------------
# It's a match!
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#    0  1  2  3
# 0 8B m0 F5 F7
# 1 F7 XX XX XX
# 2 8B XX F5 XX
# 3 XX XX m0 XX
# --------------
# Enter the coordinates for your first guess (row col, e.g., 0 1): 2 1
#    0  1  2  3
# 0 8B m0 F5 F7
# 1 F7 XX XX XX
# 2 8B 64 F5 XX
# 3 XX XX m0 XX
# --------------
# Enter the coordinates for your second guess (row col, e.g., 0 1): 3 1
#    0  1  2  3
# 0 8B m0 F5 F7
# 1 F7 XX XX XX
# 2 8B 64 F5 XX
# 3 XX 64 m0 XX
# --------------
# It's a match!
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#    0  1  2  3
# 0 8B m0 F5 F7
# 1 F7 XX XX XX
# 2 8B 64 F5 XX
# 3 XX 64 m0 XX
# --------------
# Enter the coordinates for your first guess (row col, e.g., 0 1): 2 3
#    0  1  2  3
# 0 8B m0 F5 F7
# 1 F7 XX XX XX
# 2 8B 64 F5 F1
# 3 XX 64 m0 XX
# --------------
# Enter the coordinates for your second guess (row col, e.g., 0 1): 1 1
#    0  1  2  3
# 0 8B m0 F5 F7
# 1 F7 C= XX XX
# 2 8B 64 F5 F1
# 3 XX 64 m0 XX
# --------------
# No match. Take a moment to remember their positions!
# Press Enter to continue...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#    0  1  2  3
# 0 8B m0 F5 F7
# 1 F7 XX XX XX
# 2 8B 64 F5 XX
# 3 XX 64 m0 XX
# --------------
# Enter the coordinates for your first guess (row col, e.g., 0 1): 1 1
#    0  1  2  3
# 0 8B m0 F5 F7
# 1 F7 C= XX XX
# 2 8B 64 F5 XX
# 3 XX 64 m0 XX
# --------------
# Enter the coordinates for your second guess (row col, e.g., 0 1): 3 0
#    0  1  2  3
# 0 8B m0 F5 F7
# 1 F7 C= XX XX
# 2 8B 64 F5 XX
# 3 C= 64 m0 XX
# --------------
# It's a match!
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#    0  1  2  3
# 0 8B m0 F5 F7
# 1 F7 C= XX XX
# 2 8B 64 F5 XX
# 3 C= 64 m0 XX
# --------------
# Enter the coordinates for your first guess (row col, e.g., 0 1): 3 3
#    0  1  2  3
# 0 8B m0 F5 F7
# 1 F7 C= XX XX
# 2 8B 64 F5 XX
# 3 C= 64 m0 F3
# --------------
# Enter the coordinates for your second guess (row col, e.g., 0 1): 2 3
#    0  1  2  3
# 0 8B m0 F5 F7
# 1 F7 C= XX XX
# 2 8B 64 F5 F1
# 3 C= 64 m0 F3
# --------------
# No match. Take a moment to remember their positions!
# Press Enter to continue...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#    0  1  2  3
# 0 8B m0 F5 F7
# 1 F7 C= XX XX
# 2 8B 64 F5 XX
# 3 C= 64 m0 XX
# --------------
# Enter the coordinates for your first guess (row col, e.g., 0 1): 1 2
#    0  1  2  3
# 0 8B m0 F5 F7
# 1 F7 C= F1 XX
# 2 8B 64 F5 XX
# 3 C= 64 m0 XX
# --------------
# Enter the coordinates for your second guess (row col, e.g., 0 1):  1 3
#    0  1  2  3
# 0 8B m0 F5 F7
# 1 F7 C= F1 F3
# 2 8B 64 F5 XX
# 3 C= 64 m0 XX
# --------------
# No match. Take a moment to remember their positions!
# Press Enter to continue...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#    0  1  2  3
# 0 8B m0 F5 F7
# 1 F7 C= XX XX
# 2 8B 64 F5 XX
# 3 C= 64 m0 XX
# --------------
# Enter the coordinates for your first guess (row col, e.g., 0 1):  3
# Invalid input. Enter two numbers separated by a space.
# Enter the coordinates for your first guess (row col, e.g., 0 1): 1 3
#    0  1  2  3
# 0 8B m0 F5 F7
# 1 F7 C= XX F3
# 2 8B 64 F5 XX
# 3 C= 64 m0 XX
# --------------
# Enter the coordinates for your second guess (row col, e.g., 0 1): 3 3
#    0  1  2  3
# 0 8B m0 F5 F7
# 1 F7 C= XX F3
# 2 8B 64 F5 XX
# 3 C= 64 m0 F3
# --------------
# It's a match!
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#    0  1  2  3
# 0 8B m0 F5 F7
# 1 F7 C= XX F3
# 2 8B 64 F5 XX
# 3 C= 64 m0 F3
# --------------
# Enter the coordinates for your first guess (row col, e.g., 0 1): 1 2
#    0  1  2  3
# 0 8B m0 F5 F7
# 1 F7 C= F1 F3
# 2 8B 64 F5 XX
# 3 C= 64 m0 F3
# --------------
# Enter the coordinates for your second guess (row col, e.g., 0 1): 2 3
#    0  1  2  3
# 0 8B m0 F5 F7
# 1 F7 C= F1 F3
# 2 8B 64 F5 F1
# 3 C= 64 m0 F3
# --------------
# It's a match!
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Congrats! You matched all the symbols!
